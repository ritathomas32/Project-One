# %% [markdown]
# Impact of Federal Monetary Policy on Investments

# %%
# Import libraries and dependencies
import pyfolio as pf
# import alpaca_trade_api as tradeapi
import os
import json
import numpy as np
import yfinance as yf
import pandas as pd
from dotenv import load_dotenv
# %matplotlib inline


# silence warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# /Users/robertjonathonsmart/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pyfolio/pos.py:27: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; multipliers will not be applied'

# %%
btc = yf.download("BTC-USD, ETH-USD", start="2019-01-01", end="2022-04-30")
btc.head()
# Out:
# [*********************100%***********************]  2 of 2 completed
#               Adj Close                    Close                     High  \
#                 BTC-USD     ETH-USD      BTC-USD     ETH-USD      BTC-USD
# Date
# 2018-12-31  3742.700439  133.368256  3742.700439  133.368256  3868.742920
# 2019-01-01  3843.520020  140.819412  3843.520020  140.819412  3850.913818
# 2019-01-02  3943.409424  155.047684  3943.409424  155.047684  3947.981201
# 2019-01-03  3836.741211  149.135010  3836.741211  149.135010  3935.685059
# 2019-01-04  3857.717529  154.581940  3857.717529  154.581940  3865.934570
#
#                                 Low                     Open              \
#                ETH-USD      BTC-USD     ETH-USD      BTC-USD     ETH-USD
# Date
# 2018-12-31  140.181152  3725.867432  132.519394  3866.839111  140.031067
# 2019-01-01  141.397507  3707.231201  132.650711  3746.713379  133.418152
# 2019-01-02  156.929138  3817.409424  140.650955  3849.216309  141.519516
# ...

# %%
btc.index=btc.index.tz_convert('utc')

# %%
# Out:
#                             BTC-USD   ETH-USD
# Date
# 2019-01-01 00:00:00+00:00  0.026938  0.055869
# 2019-01-02 00:00:00+00:00  0.025989  0.101039
# 2019-01-03 00:00:00+00:00 -0.027050 -0.038135
# 2019-01-04 00:00:00+00:00  0.005467  0.036523
# 2019-01-05 00:00:00+00:00 -0.003246  0.006836

# %%
# Out:
# Date
# 2017-11-10 00:00:00+00:00   -0.067411
# 2017-11-11 00:00:00+00:00    0.051555
# 2017-11-12 00:00:00+00:00   -0.021523
# 2017-11-13 00:00:00+00:00    0.028606
# 2017-11-14 00:00:00+00:00    0.066037
# Name: Close, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/t6/rm19hrvd4jv2_b0241jdhqm00000gn/T/ipykernel_62987/3727275856.py in <module>
# ----> 1 pf.create_returns_tear_sheet(btc_rets)
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pyfolio/plotting.py in call_w_context(*args, **kwargs)
#      50         if set_context:
#      51             with plotting_context(), axes_style():
# ---> 52                 return func(*args, **kwargs)
#      53         else:
#      54             return func(*args, **kwargs)
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pyfolio/tears.py in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     470                              bootstrap=bootstrap,
#     471                              live_start_date=live_start_date,
# ...

# %%
pf.create_returns_tear_sheet(eth_rets, live_start_date='2022-09-28')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=4>2017-11-10</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=4>2022-10-03</td></tr>
#     <tr style="text-align: right;"><th>In-sample months</th><td colspan=4>84</td></tr>
#     <tr style="text-align: right;"><th>Out-of-sample months</th><td colspan=4>0</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>In-sample</th>
#       <th>Out-of-sample</th>
#       <th>All</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>22.259%</td>
#       <td>-73.641%</td>
#       <td>21.631%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>314.52%</td>
#       <td>-3.125%</td>
#       <td>301.567%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>81.166%</td>
#       <td>21.105%</td>
#       <td>81.04%</td>
#     </tr>
#     <tr>
# ...

# %%
df_ticker = pd.concat([btc_hist, eth_hist], axis=1, keys=["BTC","ETH"])
df_ticker
# Out:
#                                     BTC                              \
#                                    Open          High           Low
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2022-09-29 00:00:00+00:00  19427.779297  19589.265625  18924.353516
# 2022-09-30 00:00:00+00:00  19573.431641  20109.849609  19265.662109
# 2022-10-01 00:00:00+00:00  19431.105469  19471.154297  19231.082031
# 2022-10-02 00:00:00+00:00  19311.849609  19370.308594  18970.621094
# 2022-10-03 00:00:00+00:00  19039.136719  19278.644531  19039.136719
#
# ...

# %% [markdown]
# Read in  Market Yield on U.S. Treasury Securities at 2-Year Constant Maturity, Quoted on an Investment Basis
